# %% [markdown]
# <a href="https://colab.research.google.com/github/100rab-S/TensorFlow-Advanced-Techniques/blob/main/C1W1_L2_Multi_Output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %%
## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import plot_model

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    # y1 = np.array(y1)  
    y2 = data.pop('Y2')
    # y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=len(train.columns))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 128)          1152        input_7[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 128)          16512       dense_18[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 64)           8256        dense_19[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_19[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_20[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
plot_model(model)

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 4s 7ms/step - loss: 611.3514 - y1_output_loss: 280.6615 - y2_output_loss: 330.6899 - y1_output_root_mean_squared_error: 16.1718 - y2_output_root_mean_squared_error: 17.5583 - val_loss: 39.7158 - val_y1_output_loss: 16.1526 - val_y2_output_loss: 23.5632 - val_y1_output_root_mean_squared_error: 4.0190 - val_y2_output_root_mean_squared_error: 4.8542
# Epoch 2/500
# 62/62 [==============================] - 0s 4ms/step - loss: 47.9244 - y1_output_loss: 16.6853 - y2_output_loss: 31.2391 - y1_output_root_mean_squared_error: 4.0624 - y2_output_root_mean_squared_error: 5.5242 - val_loss: 21.4522 - val_y1_output_loss: 9.0603 - val_y2_output_loss: 12.3919 - val_y1_output_root_mean_squared_error: 3.0100 - val_y2_output_root_mean_squared_error: 3.5202
# Epoch 3/500
# 62/62 [==============================] - 0s 4ms/step - loss: 25.7132 - y1_output_loss: 10.3335 - y2_output_loss: 15.3796 - y1_output_root_mean_squared_error: 3.2106 - y2_output_root_mean_squared_error: 3.9153 - val_loss: 29.9265 - val_y1_output_loss: 9.8646 - val_y2_output_loss: 20.0619 - val_y1_output_root_mean_squared_error: 3.1408 - val_y2_output_root_mean_squared_error: 4.4791
# Epoch 4/500
# 62/62 [==============================] - 0s 4ms/step - loss: 22.9585 - y1_output_loss: 9.2626 - y2_output_loss: 13.6960 - y1_output_root_mean_squared_error: 3.0326 - y2_output_root_mean_squared_error: 3.6942 - val_loss: 19.2242 - val_y1_output_loss: 8.1655 - val_y2_output_loss: 11.0587 - val_y1_output_root_mean_squared_error: 2.8575 - val_y2_output_root_mean_squared_error: 3.3255
# Epoch 5/500
# 62/62 [==============================] - 0s 4ms/step - loss: 24.0353 - y1_output_loss: 10.3458 - y2_output_loss: 13.6894 - y1_output_root_mean_squared_error: 3.2056 - y2_output_root_mean_squared_error: 3.6842 - val_loss: 15.7432 - val_y1_output_loss: 6.7348 - val_y2_output_loss: 9.0085 - val_y1_output_root_mean_squared_error: 2.5951 - val_y2_output_root_mean_squared_error: 3.0014
# Epoch 6/500
# 62/62 [==============================] - 0s 4ms/step - loss: 25.5619 - y1_output_loss: 10.0326 - y2_output_loss: 15.5293 - y1_output_root_mean_squared_error: 3.1643 - y2_output_root_mean_squared_error: 3.9286 - val_loss: 17.4647 - val_y1_output_loss: 6.7596 - val_y2_output_loss: 10.7051 - val_y1_output_root_mean_squared_error: 2.5999 - val_y2_output_root_mean_squared_error: 3.2719
# Epoch 7/500
# 62/62 [==============================] - 0s 4ms/step - loss: 26.8239 - y1_output_loss: 9.8942 - y2_output_loss: 16.9297 - y1_output_root_mean_squared_error: 3.1440 - y2_output_root_mean_squared_error: 4.1080 - val_loss: 15.2136 - val_y1_output_loss: 6.3731 - val_y2_output_loss: 8.8405 - val_y1_output_root_mean_squared_error: 2.5245 - val_y2_output_root_mean_squared_error: 2.9733
# Epoch 8/500
# 62/62 [==============================] - 0s 4ms/step - loss: 18.4354 - y1_output_loss: 7.4408 - y2_output_loss: 10.9946 - y1_output_root_mean_squared_error: 2.7228 - y2_output_root_mean_squared_error: 3.3053 - val_loss: 15.0353 - val_y1_output_loss: 6.3335 - val_y2_output_loss: 8.7018 - val_y1_output_root_mean_squared_error: 2.5167 - val_y2_output_root_mean_squared_error: 2.9499
# Epoch 9/500
# 62/62 [==============================] - 0s 4ms/step - loss: 28.6985 - y1_output_loss: 9.3312 - y2_output_loss: 19.3673 - y1_output_root_mean_squared_error: 3.0471 - y2_output_root_mean_squared_error: 4.3875 - val_loss: 26.7548 - val_y1_output_loss: 8.3048 - val_y2_output_loss: 18.4500 - val_y1_output_root_mean_squared_error: 2.8818 - val_y2_output_root_mean_squared_error: 4.2953
# Epoch 10/500
# 62/62 [==============================] - 0s 4ms/step - loss: 25.8780 - y1_output_loss: 9.6384 - y2_output_loss: 16.2397 - y1_output_root_mean_squared_error: 3.0955 - y2_output_root_mean_squared_error: 4.0197 - val_loss: 127.9873 - val_y1_output_loss: 27.6030 - val_y2_output_loss: 100.3843 - val_y1_output_root_mean_squared_error: 5.2539 - val_y2_output_root_mean_squared_error: 10.0192
# Epoch 11/500
# 62/62 [==============================] - 0s 4ms/step - loss: 31.2516 - y1_output_loss: 9.5036 - y2_output_loss: 21.7480 - y1_output_root_mean_squared_error: 3.0424 - y2_output_root_mean_squared_error: 4.4221 - val_loss: 55.4079 - val_y1_output_loss: 15.9865 - val_y2_output_loss: 39.4214 - val_y1_output_root_mean_squared_error: 3.9983 - val_y2_output_root_mean_squared_error: 6.2786
# Epoch 12/500
# 62/62 [==============================] - 0s 4ms/step - loss: 25.3065 - y1_output_loss: 8.6473 - y2_output_loss: 16.6592 - y1_output_root_mean_squared_error: 2.9199 - y2_output_root_mean_squared_error: 4.0025 - val_loss: 40.9594 - val_y1_output_loss: 12.9922 - val_y2_output_loss: 27.9672 - val_y1_output_root_mean_squared_error: 3.6045 - val_y2_output_root_mean_squared_error: 5.2884
# Epoch 13/500
# 62/62 [==============================] - 0s 4ms/step - loss: 17.9570 - y1_output_loss: 7.4829 - y2_output_loss: 10.4741 - y1_output_root_mean_squared_error: 2.7248 - y2_output_root_mean_squared_error: 3.2321 - val_loss: 14.2548 - val_y1_output_loss: 5.3628 - val_y2_output_loss: 8.8920 - val_y1_output_root_mean_squared_error: 2.3158 - val_y2_output_root_mean_squared_error: 2.9819
# Epoch 14/500
# 62/62 [==============================] - 0s 4ms/step - loss: 25.3062 - y1_output_loss: 8.5283 - y2_output_loss: 16.7779 - y1_output_root_mean_squared_error: 2.9085 - y2_output_root_mean_squared_error: 4.0588 - val_loss: 12.8530 - val_y1_output_loss: 4.9041 - val_y2_output_loss: 7.9489 - val_y1_output_root_mean_squared_error: 2.2145 - val_y2_output_root_mean_squared_error: 2.8194
# Epoch 15/500
# 62/62 [==============================] - 0s 4ms/step - loss: 16.1601 - y1_output_loss: 6.0069 - y2_output_loss: 10.1532 - y1_output_root_mean_squared_error: 2.4489 - y2_output_root_mean_squared_error: 3.1830 - val_loss: 63.7052 - val_y1_output_loss: 19.3332 - val_y2_output_loss: 44.3720 - val_y1_output_root_mean_squared_error: 4.3970 - val_y2_output_root_mean_squared_error: 6.6612
# Epoch 16/500
# 62/62 [==============================] - 0s 4ms/step - loss: 22.8855 - y1_output_loss: 7.5184 - y2_output_loss: 15.3671 - y1_output_root_mean_squared_error: 2.7134 - y2_output_root_mean_squared_error: 3.8152 - val_loss: 28.3766 - val_y1_output_loss: 7.5631 - val_y2_output_loss: 20.8135 - val_y1_output_root_mean_squared_error: 2.7501 - val_y2_output_root_mean_squared_error: 4.5622
# Epoch 17/500
# 62/62 [==============================] - 0s 4ms/step - loss: 17.4802 - y1_output_loss: 6.6019 - y2_output_loss: 10.8783 - y1_output_root_mean_squared_error: 2.5684 - y2_output_root_mean_squared_error: 3.2762 - val_loss: 15.1621 - val_y1_output_loss: 4.5122 - val_y2_output_loss: 10.6499 - val_y1_output_root_mean_squared_error: 2.1242 - val_y2_output_root_mean_squared_error: 3.2634
# Epoch 18/500
# 62/62 [==============================] - 0s 4ms/step - loss: 17.6648 - y1_output_loss: 7.3407 - y2_output_loss: 10.3241 - y1_output_root_mean_squared_error: 2.7064 - y2_output_root_mean_squared_error: 3.2067 - val_loss: 9.2900 - val_y1_output_loss: 3.7720 - val_y2_output_loss: 5.5181 - val_y1_output_root_mean_squared_error: 1.9422 - val_y2_output_root_mean_squared_error: 2.3491
# Epoch 19/500
# 62/62 [==============================] - 0s 4ms/step - loss: 11.2922 - y1_output_loss: 4.4532 - y2_output_loss: 6.8390 - y1_output_root_mean_squared_error: 2.0855 - y2_output_root_mean_squared_error: 2.5937 - val_loss: 10.9160 - val_y1_output_loss: 3.9574 - val_y2_output_loss: 6.9586 - val_y1_output_root_mean_squared_error: 1.9893 - val_y2_output_root_mean_squared_error: 2.6379
# Epoch 20/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.5141 - y1_output_loss: 5.8150 - y2_output_loss: 8.6991 - y1_output_root_mean_squared_error: 2.4051 - y2_output_root_mean_squared_error: 2.9410 - val_loss: 30.6748 - val_y1_output_loss: 6.7894 - val_y2_output_loss: 23.8854 - val_y1_output_root_mean_squared_error: 2.6056 - val_y2_output_root_mean_squared_error: 4.8873
# Epoch 21/500
# 62/62 [==============================] - 0s 4ms/step - loss: 18.9065 - y1_output_loss: 6.2580 - y2_output_loss: 12.6485 - y1_output_root_mean_squared_error: 2.4929 - y2_output_root_mean_squared_error: 3.4817 - val_loss: 8.5184 - val_y1_output_loss: 3.4029 - val_y2_output_loss: 5.1156 - val_y1_output_root_mean_squared_error: 1.8447 - val_y2_output_root_mean_squared_error: 2.2618
# Epoch 22/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.1013 - y1_output_loss: 5.2172 - y2_output_loss: 7.8842 - y1_output_root_mean_squared_error: 2.2794 - y2_output_root_mean_squared_error: 2.7928 - val_loss: 52.4151 - val_y1_output_loss: 9.7370 - val_y2_output_loss: 42.6780 - val_y1_output_root_mean_squared_error: 3.1204 - val_y2_output_root_mean_squared_error: 6.5328
# Epoch 23/500
# 62/62 [==============================] - 0s 4ms/step - loss: 16.4954 - y1_output_loss: 5.8108 - y2_output_loss: 10.6846 - y1_output_root_mean_squared_error: 2.4022 - y2_output_root_mean_squared_error: 3.1936 - val_loss: 9.4091 - val_y1_output_loss: 4.0039 - val_y2_output_loss: 5.4052 - val_y1_output_root_mean_squared_error: 2.0010 - val_y2_output_root_mean_squared_error: 2.3249
# Epoch 24/500
# 62/62 [==============================] - 0s 4ms/step - loss: 12.6446 - y1_output_loss: 4.9520 - y2_output_loss: 7.6926 - y1_output_root_mean_squared_error: 2.2224 - y2_output_root_mean_squared_error: 2.7708 - val_loss: 12.3878 - val_y1_output_loss: 4.7903 - val_y2_output_loss: 7.5975 - val_y1_output_root_mean_squared_error: 2.1887 - val_y2_output_root_mean_squared_error: 2.7564
# Epoch 25/500
# 62/62 [==============================] - 0s 4ms/step - loss: 15.1059 - y1_output_loss: 5.6447 - y2_output_loss: 9.4612 - y1_output_root_mean_squared_error: 2.3729 - y2_output_root_mean_squared_error: 3.0670 - val_loss: 28.9502 - val_y1_output_loss: 7.2130 - val_y2_output_loss: 21.7372 - val_y1_output_root_mean_squared_error: 2.6857 - val_y2_output_root_mean_squared_error: 4.6623
# Epoch 26/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.0585 - y1_output_loss: 4.8945 - y2_output_loss: 9.1640 - y1_output_root_mean_squared_error: 2.2064 - y2_output_root_mean_squared_error: 3.0200 - val_loss: 22.8250 - val_y1_output_loss: 6.7933 - val_y2_output_loss: 16.0317 - val_y1_output_root_mean_squared_error: 2.6064 - val_y2_output_root_mean_squared_error: 4.0040
# Epoch 27/500
# 62/62 [==============================] - 0s 4ms/step - loss: 17.6505 - y1_output_loss: 6.4351 - y2_output_loss: 11.2154 - y1_output_root_mean_squared_error: 2.5053 - y2_output_root_mean_squared_error: 3.2759 - val_loss: 9.2147 - val_y1_output_loss: 2.6328 - val_y2_output_loss: 6.5819 - val_y1_output_root_mean_squared_error: 1.6226 - val_y2_output_root_mean_squared_error: 2.5655
# Epoch 28/500
# 62/62 [==============================] - 0s 4ms/step - loss: 11.1354 - y1_output_loss: 3.9545 - y2_output_loss: 7.1809 - y1_output_root_mean_squared_error: 1.9855 - y2_output_root_mean_squared_error: 2.6750 - val_loss: 9.0765 - val_y1_output_loss: 3.3937 - val_y2_output_loss: 5.6828 - val_y1_output_root_mean_squared_error: 1.8422 - val_y2_output_root_mean_squared_error: 2.3839
# Epoch 29/500
# 62/62 [==============================] - 0s 4ms/step - loss: 12.2961 - y1_output_loss: 4.2683 - y2_output_loss: 8.0278 - y1_output_root_mean_squared_error: 2.0578 - y2_output_root_mean_squared_error: 2.8294 - val_loss: 10.5705 - val_y1_output_loss: 4.0240 - val_y2_output_loss: 6.5465 - val_y1_output_root_mean_squared_error: 2.0060 - val_y2_output_root_mean_squared_error: 2.5586
# Epoch 30/500
# 62/62 [==============================] - 0s 4ms/step - loss: 12.7894 - y1_output_loss: 4.5856 - y2_output_loss: 8.2038 - y1_output_root_mean_squared_error: 2.1377 - y2_output_root_mean_squared_error: 2.8604 - val_loss: 6.7238 - val_y1_output_loss: 2.4128 - val_y2_output_loss: 4.3110 - val_y1_output_root_mean_squared_error: 1.5533 - val_y2_output_root_mean_squared_error: 2.0763
# Epoch 31/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.3025 - y1_output_loss: 3.5351 - y2_output_loss: 6.7674 - y1_output_root_mean_squared_error: 1.8726 - y2_output_root_mean_squared_error: 2.5978 - val_loss: 11.9173 - val_y1_output_loss: 4.1181 - val_y2_output_loss: 7.7993 - val_y1_output_root_mean_squared_error: 2.0293 - val_y2_output_root_mean_squared_error: 2.7927
# Epoch 32/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.4290 - y1_output_loss: 4.7410 - y2_output_loss: 8.6880 - y1_output_root_mean_squared_error: 2.1575 - y2_output_root_mean_squared_error: 2.9272 - val_loss: 7.5747 - val_y1_output_loss: 2.5746 - val_y2_output_loss: 5.0001 - val_y1_output_root_mean_squared_error: 1.6046 - val_y2_output_root_mean_squared_error: 2.2361
# Epoch 33/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.9505 - y1_output_loss: 4.2326 - y2_output_loss: 6.7180 - y1_output_root_mean_squared_error: 2.0542 - y2_output_root_mean_squared_error: 2.5870 - val_loss: 10.3919 - val_y1_output_loss: 3.1579 - val_y2_output_loss: 7.2340 - val_y1_output_root_mean_squared_error: 1.7770 - val_y2_output_root_mean_squared_error: 2.6896
# Epoch 34/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.2244 - y1_output_loss: 4.7110 - y2_output_loss: 9.5133 - y1_output_root_mean_squared_error: 2.1666 - y2_output_root_mean_squared_error: 3.0717 - val_loss: 13.6539 - val_y1_output_loss: 4.0960 - val_y2_output_loss: 9.5579 - val_y1_output_root_mean_squared_error: 2.0239 - val_y2_output_root_mean_squared_error: 3.0916
# Epoch 35/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.7593 - y1_output_loss: 2.5404 - y2_output_loss: 5.2189 - y1_output_root_mean_squared_error: 1.5846 - y2_output_root_mean_squared_error: 2.2793 - val_loss: 6.7527 - val_y1_output_loss: 2.3537 - val_y2_output_loss: 4.3989 - val_y1_output_root_mean_squared_error: 1.5342 - val_y2_output_root_mean_squared_error: 2.0974
# Epoch 36/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.2811 - y1_output_loss: 2.6805 - y2_output_loss: 4.6006 - y1_output_root_mean_squared_error: 1.6353 - y2_output_root_mean_squared_error: 2.1428 - val_loss: 6.9143 - val_y1_output_loss: 2.0494 - val_y2_output_loss: 4.8649 - val_y1_output_root_mean_squared_error: 1.4316 - val_y2_output_root_mean_squared_error: 2.2056
# Epoch 37/500
# 62/62 [==============================] - 0s 4ms/step - loss: 11.9234 - y1_output_loss: 3.6363 - y2_output_loss: 8.2871 - y1_output_root_mean_squared_error: 1.9021 - y2_output_root_mean_squared_error: 2.8603 - val_loss: 6.4672 - val_y1_output_loss: 2.2579 - val_y2_output_loss: 4.2093 - val_y1_output_root_mean_squared_error: 1.5026 - val_y2_output_root_mean_squared_error: 2.0517
# Epoch 38/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.8409 - y1_output_loss: 2.5573 - y2_output_loss: 5.2837 - y1_output_root_mean_squared_error: 1.5966 - y2_output_root_mean_squared_error: 2.2960 - val_loss: 17.7377 - val_y1_output_loss: 5.9237 - val_y2_output_loss: 11.8140 - val_y1_output_root_mean_squared_error: 2.4339 - val_y2_output_root_mean_squared_error: 3.4371
# Epoch 39/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.0167 - y1_output_loss: 3.3036 - y2_output_loss: 5.7131 - y1_output_root_mean_squared_error: 1.7948 - y2_output_root_mean_squared_error: 2.3856 - val_loss: 30.6665 - val_y1_output_loss: 10.8021 - val_y2_output_loss: 19.8644 - val_y1_output_root_mean_squared_error: 3.2867 - val_y2_output_root_mean_squared_error: 4.4570
# Epoch 40/500
# 62/62 [==============================] - 0s 4ms/step - loss: 12.9026 - y1_output_loss: 4.0023 - y2_output_loss: 8.9002 - y1_output_root_mean_squared_error: 1.9617 - y2_output_root_mean_squared_error: 2.8960 - val_loss: 23.7000 - val_y1_output_loss: 7.9219 - val_y2_output_loss: 15.7781 - val_y1_output_root_mean_squared_error: 2.8146 - val_y2_output_root_mean_squared_error: 3.9722
# Epoch 41/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.8039 - y1_output_loss: 2.8966 - y2_output_loss: 6.9073 - y1_output_root_mean_squared_error: 1.6858 - y2_output_root_mean_squared_error: 2.5563 - val_loss: 30.0117 - val_y1_output_loss: 10.2874 - val_y2_output_loss: 19.7243 - val_y1_output_root_mean_squared_error: 3.2074 - val_y2_output_root_mean_squared_error: 4.4412
# Epoch 42/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.7521 - y1_output_loss: 2.8454 - y2_output_loss: 5.9067 - y1_output_root_mean_squared_error: 1.6795 - y2_output_root_mean_squared_error: 2.4225 - val_loss: 7.1189 - val_y1_output_loss: 2.1829 - val_y2_output_loss: 4.9360 - val_y1_output_root_mean_squared_error: 1.4775 - val_y2_output_root_mean_squared_error: 2.2217
# Epoch 43/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.3900 - y1_output_loss: 2.8452 - y2_output_loss: 6.5448 - y1_output_root_mean_squared_error: 1.6835 - y2_output_root_mean_squared_error: 2.5521 - val_loss: 8.8503 - val_y1_output_loss: 2.5405 - val_y2_output_loss: 6.3098 - val_y1_output_root_mean_squared_error: 1.5939 - val_y2_output_root_mean_squared_error: 2.5119
# Epoch 44/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.7407 - y1_output_loss: 2.3929 - y2_output_loss: 4.3478 - y1_output_root_mean_squared_error: 1.5454 - y2_output_root_mean_squared_error: 2.0833 - val_loss: 14.4757 - val_y1_output_loss: 2.9941 - val_y2_output_loss: 11.4815 - val_y1_output_root_mean_squared_error: 1.7304 - val_y2_output_root_mean_squared_error: 3.3884
# Epoch 45/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.6698 - y1_output_loss: 2.0411 - y2_output_loss: 4.6287 - y1_output_root_mean_squared_error: 1.4230 - y2_output_root_mean_squared_error: 2.1497 - val_loss: 5.1811 - val_y1_output_loss: 1.8209 - val_y2_output_loss: 3.3602 - val_y1_output_root_mean_squared_error: 1.3494 - val_y2_output_root_mean_squared_error: 1.8331
# Epoch 46/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.8213 - y1_output_loss: 2.1903 - y2_output_loss: 4.6310 - y1_output_root_mean_squared_error: 1.4699 - y2_output_root_mean_squared_error: 2.1300 - val_loss: 5.9273 - val_y1_output_loss: 1.8198 - val_y2_output_loss: 4.1075 - val_y1_output_root_mean_squared_error: 1.3490 - val_y2_output_root_mean_squared_error: 2.0267
# Epoch 47/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.9646 - y1_output_loss: 1.9754 - y2_output_loss: 3.9892 - y1_output_root_mean_squared_error: 1.4026 - y2_output_root_mean_squared_error: 1.9932 - val_loss: 5.1569 - val_y1_output_loss: 1.9380 - val_y2_output_loss: 3.2189 - val_y1_output_root_mean_squared_error: 1.3921 - val_y2_output_root_mean_squared_error: 1.7941
# Epoch 48/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.0387 - y1_output_loss: 2.8590 - y2_output_loss: 6.1797 - y1_output_root_mean_squared_error: 1.6857 - y2_output_root_mean_squared_error: 2.4729 - val_loss: 12.2567 - val_y1_output_loss: 3.4291 - val_y2_output_loss: 8.8276 - val_y1_output_root_mean_squared_error: 1.8518 - val_y2_output_root_mean_squared_error: 2.9711
# Epoch 49/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.5042 - y1_output_loss: 2.4123 - y2_output_loss: 6.0919 - y1_output_root_mean_squared_error: 1.5500 - y2_output_root_mean_squared_error: 2.4447 - val_loss: 33.8249 - val_y1_output_loss: 6.4653 - val_y2_output_loss: 27.3596 - val_y1_output_root_mean_squared_error: 2.5427 - val_y2_output_root_mean_squared_error: 5.2306
# Epoch 50/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.2752 - y1_output_loss: 3.1455 - y2_output_loss: 6.1298 - y1_output_root_mean_squared_error: 1.7437 - y2_output_root_mean_squared_error: 2.4333 - val_loss: 4.3127 - val_y1_output_loss: 1.5408 - val_y2_output_loss: 2.7719 - val_y1_output_root_mean_squared_error: 1.2413 - val_y2_output_root_mean_squared_error: 1.6649
# Epoch 51/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.2324 - y1_output_loss: 1.9355 - y2_output_loss: 5.2969 - y1_output_root_mean_squared_error: 1.3762 - y2_output_root_mean_squared_error: 2.2931 - val_loss: 6.2283 - val_y1_output_loss: 1.7182 - val_y2_output_loss: 4.5100 - val_y1_output_root_mean_squared_error: 1.3108 - val_y2_output_root_mean_squared_error: 2.1237
# Epoch 52/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.7075 - y1_output_loss: 1.7506 - y2_output_loss: 3.9568 - y1_output_root_mean_squared_error: 1.3201 - y2_output_root_mean_squared_error: 1.9752 - val_loss: 13.7813 - val_y1_output_loss: 3.3668 - val_y2_output_loss: 10.4144 - val_y1_output_root_mean_squared_error: 1.8349 - val_y2_output_root_mean_squared_error: 3.2271
# Epoch 53/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.2604 - y1_output_loss: 3.1007 - y2_output_loss: 6.1597 - y1_output_root_mean_squared_error: 1.7404 - y2_output_root_mean_squared_error: 2.4576 - val_loss: 4.6136 - val_y1_output_loss: 1.5169 - val_y2_output_loss: 3.0966 - val_y1_output_root_mean_squared_error: 1.2316 - val_y2_output_root_mean_squared_error: 1.7597
# Epoch 54/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.9057 - y1_output_loss: 1.6571 - y2_output_loss: 4.2486 - y1_output_root_mean_squared_error: 1.2846 - y2_output_root_mean_squared_error: 2.0597 - val_loss: 4.7455 - val_y1_output_loss: 1.6410 - val_y2_output_loss: 3.1044 - val_y1_output_root_mean_squared_error: 1.2810 - val_y2_output_root_mean_squared_error: 1.7619
# Epoch 55/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.7656 - y1_output_loss: 1.4616 - y2_output_loss: 3.3040 - y1_output_root_mean_squared_error: 1.2073 - y2_output_root_mean_squared_error: 1.8156 - val_loss: 5.9181 - val_y1_output_loss: 2.4197 - val_y2_output_loss: 3.4984 - val_y1_output_root_mean_squared_error: 1.5555 - val_y2_output_root_mean_squared_error: 1.8704
# Epoch 56/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.5592 - y1_output_loss: 2.1518 - y2_output_loss: 5.4075 - y1_output_root_mean_squared_error: 1.4629 - y2_output_root_mean_squared_error: 2.3107 - val_loss: 4.9127 - val_y1_output_loss: 1.8681 - val_y2_output_loss: 3.0445 - val_y1_output_root_mean_squared_error: 1.3668 - val_y2_output_root_mean_squared_error: 1.7449
# Epoch 57/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.1909 - y1_output_loss: 1.6257 - y2_output_loss: 3.5652 - y1_output_root_mean_squared_error: 1.2718 - y2_output_root_mean_squared_error: 1.8765 - val_loss: 5.5699 - val_y1_output_loss: 1.6583 - val_y2_output_loss: 3.9116 - val_y1_output_root_mean_squared_error: 1.2877 - val_y2_output_root_mean_squared_error: 1.9778
# Epoch 58/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.1644 - y1_output_loss: 1.6624 - y2_output_loss: 3.5020 - y1_output_root_mean_squared_error: 1.2854 - y2_output_root_mean_squared_error: 1.8611 - val_loss: 6.3869 - val_y1_output_loss: 1.3386 - val_y2_output_loss: 5.0484 - val_y1_output_root_mean_squared_error: 1.1570 - val_y2_output_root_mean_squared_error: 2.2469
# Epoch 59/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.2836 - y1_output_loss: 1.5538 - y2_output_loss: 3.7297 - y1_output_root_mean_squared_error: 1.2427 - y2_output_root_mean_squared_error: 1.9269 - val_loss: 3.9821 - val_y1_output_loss: 1.3390 - val_y2_output_loss: 2.6430 - val_y1_output_root_mean_squared_error: 1.1572 - val_y2_output_root_mean_squared_error: 1.6257
# Epoch 60/500
# 62/62 [==============================] - 0s 4ms/step - loss: 11.0198 - y1_output_loss: 3.1925 - y2_output_loss: 7.8273 - y1_output_root_mean_squared_error: 1.6846 - y2_output_root_mean_squared_error: 2.6792 - val_loss: 8.7377 - val_y1_output_loss: 1.7596 - val_y2_output_loss: 6.9781 - val_y1_output_root_mean_squared_error: 1.3265 - val_y2_output_root_mean_squared_error: 2.6416
# Epoch 61/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.9475 - y1_output_loss: 1.5508 - y2_output_loss: 3.3967 - y1_output_root_mean_squared_error: 1.2443 - y2_output_root_mean_squared_error: 1.8398 - val_loss: 4.5412 - val_y1_output_loss: 1.4616 - val_y2_output_loss: 3.0797 - val_y1_output_root_mean_squared_error: 1.2089 - val_y2_output_root_mean_squared_error: 1.7549
# Epoch 62/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.7576 - y1_output_loss: 1.6518 - y2_output_loss: 4.1058 - y1_output_root_mean_squared_error: 1.2825 - y2_output_root_mean_squared_error: 2.0227 - val_loss: 3.8865 - val_y1_output_loss: 1.3700 - val_y2_output_loss: 2.5165 - val_y1_output_root_mean_squared_error: 1.1705 - val_y2_output_root_mean_squared_error: 1.5863
# Epoch 63/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.9983 - y1_output_loss: 1.1160 - y2_output_loss: 2.8823 - y1_output_root_mean_squared_error: 1.0535 - y2_output_root_mean_squared_error: 1.6890 - val_loss: 5.1261 - val_y1_output_loss: 1.6795 - val_y2_output_loss: 3.4466 - val_y1_output_root_mean_squared_error: 1.2960 - val_y2_output_root_mean_squared_error: 1.8565
# Epoch 64/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.2569 - y1_output_loss: 1.5315 - y2_output_loss: 3.7253 - y1_output_root_mean_squared_error: 1.2344 - y2_output_root_mean_squared_error: 1.9253 - val_loss: 4.3383 - val_y1_output_loss: 1.5792 - val_y2_output_loss: 2.7592 - val_y1_output_root_mean_squared_error: 1.2566 - val_y2_output_root_mean_squared_error: 1.6611
# Epoch 65/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.2099 - y1_output_loss: 1.2946 - y2_output_loss: 2.9153 - y1_output_root_mean_squared_error: 1.1333 - y2_output_root_mean_squared_error: 1.7068 - val_loss: 3.3684 - val_y1_output_loss: 1.0568 - val_y2_output_loss: 2.3116 - val_y1_output_root_mean_squared_error: 1.0280 - val_y2_output_root_mean_squared_error: 1.5204
# Epoch 66/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.6900 - y1_output_loss: 1.7231 - y2_output_loss: 4.9669 - y1_output_root_mean_squared_error: 1.3038 - y2_output_root_mean_squared_error: 2.2160 - val_loss: 4.6408 - val_y1_output_loss: 1.4778 - val_y2_output_loss: 3.1631 - val_y1_output_root_mean_squared_error: 1.2156 - val_y2_output_root_mean_squared_error: 1.7785
# Epoch 67/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.8383 - y1_output_loss: 2.0774 - y2_output_loss: 5.7608 - y1_output_root_mean_squared_error: 1.4317 - y2_output_root_mean_squared_error: 2.3829 - val_loss: 4.8593 - val_y1_output_loss: 1.4546 - val_y2_output_loss: 3.4047 - val_y1_output_root_mean_squared_error: 1.2061 - val_y2_output_root_mean_squared_error: 1.8452
# Epoch 68/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.1017 - y1_output_loss: 1.3550 - y2_output_loss: 2.7466 - y1_output_root_mean_squared_error: 1.1593 - y2_output_root_mean_squared_error: 1.6435 - val_loss: 10.4593 - val_y1_output_loss: 1.5286 - val_y2_output_loss: 8.9307 - val_y1_output_root_mean_squared_error: 1.2364 - val_y2_output_root_mean_squared_error: 2.9884
# Epoch 69/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.7681 - y1_output_loss: 1.4254 - y2_output_loss: 3.3428 - y1_output_root_mean_squared_error: 1.1916 - y2_output_root_mean_squared_error: 1.8244 - val_loss: 9.0945 - val_y1_output_loss: 2.0536 - val_y2_output_loss: 7.0409 - val_y1_output_root_mean_squared_error: 1.4331 - val_y2_output_root_mean_squared_error: 2.6535
# Epoch 70/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.4431 - y1_output_loss: 1.3954 - y2_output_loss: 4.0476 - y1_output_root_mean_squared_error: 1.1758 - y2_output_root_mean_squared_error: 1.9907 - val_loss: 5.9202 - val_y1_output_loss: 1.6218 - val_y2_output_loss: 4.2985 - val_y1_output_root_mean_squared_error: 1.2735 - val_y2_output_root_mean_squared_error: 2.0733
# Epoch 71/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.5128 - y1_output_loss: 1.0707 - y2_output_loss: 2.4422 - y1_output_root_mean_squared_error: 1.0333 - y2_output_root_mean_squared_error: 1.5597 - val_loss: 3.3896 - val_y1_output_loss: 0.8819 - val_y2_output_loss: 2.5077 - val_y1_output_root_mean_squared_error: 0.9391 - val_y2_output_root_mean_squared_error: 1.5836
# Epoch 72/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.9894 - y1_output_loss: 1.0845 - y2_output_loss: 2.9049 - y1_output_root_mean_squared_error: 1.0353 - y2_output_root_mean_squared_error: 1.6965 - val_loss: 4.3449 - val_y1_output_loss: 1.9095 - val_y2_output_loss: 2.4354 - val_y1_output_root_mean_squared_error: 1.3818 - val_y2_output_root_mean_squared_error: 1.5606
# Epoch 73/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.2488 - y1_output_loss: 2.8238 - y2_output_loss: 5.4251 - y1_output_root_mean_squared_error: 1.6598 - y2_output_root_mean_squared_error: 2.3088 - val_loss: 8.6801 - val_y1_output_loss: 1.8446 - val_y2_output_loss: 6.8356 - val_y1_output_root_mean_squared_error: 1.3581 - val_y2_output_root_mean_squared_error: 2.6145
# Epoch 74/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.8827 - y1_output_loss: 1.3610 - y2_output_loss: 3.5216 - y1_output_root_mean_squared_error: 1.1518 - y2_output_root_mean_squared_error: 1.8610 - val_loss: 28.6403 - val_y1_output_loss: 7.8901 - val_y2_output_loss: 20.7502 - val_y1_output_root_mean_squared_error: 2.8089 - val_y2_output_root_mean_squared_error: 4.5552
# Epoch 75/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.7165 - y1_output_loss: 2.3929 - y2_output_loss: 4.3236 - y1_output_root_mean_squared_error: 1.4690 - y2_output_root_mean_squared_error: 2.0296 - val_loss: 3.8521 - val_y1_output_loss: 0.6365 - val_y2_output_loss: 3.2156 - val_y1_output_root_mean_squared_error: 0.7978 - val_y2_output_root_mean_squared_error: 1.7932
# Epoch 76/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.4623 - y1_output_loss: 0.8726 - y2_output_loss: 2.5897 - y1_output_root_mean_squared_error: 0.9324 - y2_output_root_mean_squared_error: 1.6083 - val_loss: 3.2008 - val_y1_output_loss: 1.0632 - val_y2_output_loss: 2.1376 - val_y1_output_root_mean_squared_error: 1.0311 - val_y2_output_root_mean_squared_error: 1.4621
# Epoch 77/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.5379 - y1_output_loss: 1.0323 - y2_output_loss: 2.5057 - y1_output_root_mean_squared_error: 1.0129 - y2_output_root_mean_squared_error: 1.5766 - val_loss: 3.7639 - val_y1_output_loss: 1.0929 - val_y2_output_loss: 2.6710 - val_y1_output_root_mean_squared_error: 1.0454 - val_y2_output_root_mean_squared_error: 1.6343
# Epoch 78/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.5769 - y1_output_loss: 1.3570 - y2_output_loss: 3.2200 - y1_output_root_mean_squared_error: 1.1543 - y2_output_root_mean_squared_error: 1.7797 - val_loss: 12.5017 - val_y1_output_loss: 2.3768 - val_y2_output_loss: 10.1249 - val_y1_output_root_mean_squared_error: 1.5417 - val_y2_output_root_mean_squared_error: 3.1820
# Epoch 79/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.2622 - y1_output_loss: 1.0168 - y2_output_loss: 3.2454 - y1_output_root_mean_squared_error: 1.0039 - y2_output_root_mean_squared_error: 1.7895 - val_loss: 3.2321 - val_y1_output_loss: 0.8947 - val_y2_output_loss: 2.3374 - val_y1_output_root_mean_squared_error: 0.9459 - val_y2_output_root_mean_squared_error: 1.5289
# Epoch 80/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.3199 - y1_output_loss: 1.1481 - y2_output_loss: 4.1718 - y1_output_root_mean_squared_error: 1.0700 - y2_output_root_mean_squared_error: 2.0198 - val_loss: 2.4687 - val_y1_output_loss: 0.5865 - val_y2_output_loss: 1.8822 - val_y1_output_root_mean_squared_error: 0.7658 - val_y2_output_root_mean_squared_error: 1.3719
# Epoch 81/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.8247 - y1_output_loss: 0.8213 - y2_output_loss: 2.0033 - y1_output_root_mean_squared_error: 0.9057 - y2_output_root_mean_squared_error: 1.4114 - val_loss: 2.7035 - val_y1_output_loss: 0.8803 - val_y2_output_loss: 1.8232 - val_y1_output_root_mean_squared_error: 0.9382 - val_y2_output_root_mean_squared_error: 1.3503
# Epoch 82/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.0586 - y1_output_loss: 0.6579 - y2_output_loss: 2.4008 - y1_output_root_mean_squared_error: 0.8098 - y2_output_root_mean_squared_error: 1.5446 - val_loss: 4.9747 - val_y1_output_loss: 1.4529 - val_y2_output_loss: 3.5219 - val_y1_output_root_mean_squared_error: 1.2054 - val_y2_output_root_mean_squared_error: 1.8767
# Epoch 83/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.2416 - y1_output_loss: 0.7163 - y2_output_loss: 2.5253 - y1_output_root_mean_squared_error: 0.8443 - y2_output_root_mean_squared_error: 1.5801 - val_loss: 4.5718 - val_y1_output_loss: 1.5724 - val_y2_output_loss: 2.9993 - val_y1_output_root_mean_squared_error: 1.2540 - val_y2_output_root_mean_squared_error: 1.7319
# Epoch 84/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.8398 - y1_output_loss: 1.2351 - y2_output_loss: 3.6048 - y1_output_root_mean_squared_error: 1.1079 - y2_output_root_mean_squared_error: 1.8952 - val_loss: 2.6922 - val_y1_output_loss: 0.7218 - val_y2_output_loss: 1.9704 - val_y1_output_root_mean_squared_error: 0.8496 - val_y2_output_root_mean_squared_error: 1.4037
# Epoch 85/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.0672 - y1_output_loss: 0.7563 - y2_output_loss: 2.3109 - y1_output_root_mean_squared_error: 0.8662 - y2_output_root_mean_squared_error: 1.5011 - val_loss: 2.7652 - val_y1_output_loss: 0.8444 - val_y2_output_loss: 1.9208 - val_y1_output_root_mean_squared_error: 0.9189 - val_y2_output_root_mean_squared_error: 1.3859
# Epoch 86/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.6524 - y1_output_loss: 1.5974 - y2_output_loss: 4.0550 - y1_output_root_mean_squared_error: 1.2341 - y2_output_root_mean_squared_error: 1.9548 - val_loss: 5.7580 - val_y1_output_loss: 1.2966 - val_y2_output_loss: 4.4614 - val_y1_output_root_mean_squared_error: 1.1387 - val_y2_output_root_mean_squared_error: 2.1122
# Epoch 87/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.8267 - y1_output_loss: 0.8026 - y2_output_loss: 2.0241 - y1_output_root_mean_squared_error: 0.8927 - y2_output_root_mean_squared_error: 1.4202 - val_loss: 10.5498 - val_y1_output_loss: 2.1786 - val_y2_output_loss: 8.3712 - val_y1_output_root_mean_squared_error: 1.4760 - val_y2_output_root_mean_squared_error: 2.8933
# Epoch 88/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.1227 - y1_output_loss: 0.9456 - y2_output_loss: 2.1771 - y1_output_root_mean_squared_error: 0.9691 - y2_output_root_mean_squared_error: 1.4731 - val_loss: 3.6275 - val_y1_output_loss: 0.8658 - val_y2_output_loss: 2.7617 - val_y1_output_root_mean_squared_error: 0.9305 - val_y2_output_root_mean_squared_error: 1.6618
# Epoch 89/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.7337 - y1_output_loss: 2.9982 - y2_output_loss: 7.7355 - y1_output_root_mean_squared_error: 1.6778 - y2_output_root_mean_squared_error: 2.7117 - val_loss: 2.7297 - val_y1_output_loss: 0.5017 - val_y2_output_loss: 2.2280 - val_y1_output_root_mean_squared_error: 0.7083 - val_y2_output_root_mean_squared_error: 1.4926
# Epoch 90/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.2513 - y1_output_loss: 0.6664 - y2_output_loss: 1.5849 - y1_output_root_mean_squared_error: 0.8142 - y2_output_root_mean_squared_error: 1.2558 - val_loss: 2.6315 - val_y1_output_loss: 0.6415 - val_y2_output_loss: 1.9900 - val_y1_output_root_mean_squared_error: 0.8009 - val_y2_output_root_mean_squared_error: 1.4107
# Epoch 91/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.6052 - y1_output_loss: 0.6249 - y2_output_loss: 1.9802 - y1_output_root_mean_squared_error: 0.7901 - y2_output_root_mean_squared_error: 1.4038 - val_loss: 2.3831 - val_y1_output_loss: 0.6588 - val_y2_output_loss: 1.7243 - val_y1_output_root_mean_squared_error: 0.8117 - val_y2_output_root_mean_squared_error: 1.3131
# Epoch 92/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5215 - y1_output_loss: 0.6410 - y2_output_loss: 1.8805 - y1_output_root_mean_squared_error: 0.7987 - y2_output_root_mean_squared_error: 1.3664 - val_loss: 4.5260 - val_y1_output_loss: 1.7768 - val_y2_output_loss: 2.7492 - val_y1_output_root_mean_squared_error: 1.3330 - val_y2_output_root_mean_squared_error: 1.6581
# Epoch 93/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.8768 - y1_output_loss: 0.6916 - y2_output_loss: 2.1852 - y1_output_root_mean_squared_error: 0.8295 - y2_output_root_mean_squared_error: 1.4752 - val_loss: 2.5733 - val_y1_output_loss: 0.5190 - val_y2_output_loss: 2.0543 - val_y1_output_root_mean_squared_error: 0.7204 - val_y2_output_root_mean_squared_error: 1.4333
# Epoch 94/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1112 - y1_output_loss: 0.5385 - y2_output_loss: 1.5727 - y1_output_root_mean_squared_error: 0.7322 - y2_output_root_mean_squared_error: 1.2462 - val_loss: 3.3628 - val_y1_output_loss: 0.5403 - val_y2_output_loss: 2.8226 - val_y1_output_root_mean_squared_error: 0.7350 - val_y2_output_root_mean_squared_error: 1.6800
# Epoch 95/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1766 - y1_output_loss: 0.6522 - y2_output_loss: 1.5243 - y1_output_root_mean_squared_error: 0.8052 - y2_output_root_mean_squared_error: 1.2330 - val_loss: 2.5459 - val_y1_output_loss: 0.5064 - val_y2_output_loss: 2.0395 - val_y1_output_root_mean_squared_error: 0.7116 - val_y2_output_root_mean_squared_error: 1.4281
# Epoch 96/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.7086 - y1_output_loss: 0.6687 - y2_output_loss: 2.0399 - y1_output_root_mean_squared_error: 0.8159 - y2_output_root_mean_squared_error: 1.4248 - val_loss: 2.4389 - val_y1_output_loss: 0.6939 - val_y2_output_loss: 1.7449 - val_y1_output_root_mean_squared_error: 0.8330 - val_y2_output_root_mean_squared_error: 1.3210
# Epoch 97/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.6708 - y1_output_loss: 0.9819 - y2_output_loss: 2.6890 - y1_output_root_mean_squared_error: 0.9838 - y2_output_root_mean_squared_error: 1.6247 - val_loss: 2.7138 - val_y1_output_loss: 0.5631 - val_y2_output_loss: 2.1508 - val_y1_output_root_mean_squared_error: 0.7504 - val_y2_output_root_mean_squared_error: 1.4665
# Epoch 98/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.4282 - y1_output_loss: 0.8446 - y2_output_loss: 2.5836 - y1_output_root_mean_squared_error: 0.9088 - y2_output_root_mean_squared_error: 1.5887 - val_loss: 5.5463 - val_y1_output_loss: 1.3275 - val_y2_output_loss: 4.2188 - val_y1_output_root_mean_squared_error: 1.1522 - val_y2_output_root_mean_squared_error: 2.0540
# Epoch 99/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.4419 - y1_output_loss: 0.5587 - y2_output_loss: 1.8831 - y1_output_root_mean_squared_error: 0.7452 - y2_output_root_mean_squared_error: 1.3709 - val_loss: 2.5660 - val_y1_output_loss: 0.7486 - val_y2_output_loss: 1.8175 - val_y1_output_root_mean_squared_error: 0.8652 - val_y2_output_root_mean_squared_error: 1.3481
# Epoch 100/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.2635 - y1_output_loss: 0.5058 - y2_output_loss: 1.7577 - y1_output_root_mean_squared_error: 0.7105 - y2_output_root_mean_squared_error: 1.3213 - val_loss: 3.5287 - val_y1_output_loss: 0.7581 - val_y2_output_loss: 2.7706 - val_y1_output_root_mean_squared_error: 0.8707 - val_y2_output_root_mean_squared_error: 1.6645
# Epoch 101/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.2730 - y1_output_loss: 0.5251 - y2_output_loss: 1.7479 - y1_output_root_mean_squared_error: 0.7229 - y2_output_root_mean_squared_error: 1.3194 - val_loss: 5.1267 - val_y1_output_loss: 0.7021 - val_y2_output_loss: 4.4245 - val_y1_output_root_mean_squared_error: 0.8379 - val_y2_output_root_mean_squared_error: 2.1035
# Epoch 102/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.7522 - y1_output_loss: 0.5065 - y2_output_loss: 1.2457 - y1_output_root_mean_squared_error: 0.7097 - y2_output_root_mean_squared_error: 1.1091 - val_loss: 2.6120 - val_y1_output_loss: 0.6449 - val_y2_output_loss: 1.9671 - val_y1_output_root_mean_squared_error: 0.8031 - val_y2_output_root_mean_squared_error: 1.4025
# Epoch 103/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.4498 - y1_output_loss: 1.2271 - y2_output_loss: 3.2227 - y1_output_root_mean_squared_error: 1.0988 - y2_output_root_mean_squared_error: 1.7847 - val_loss: 2.1814 - val_y1_output_loss: 0.5303 - val_y2_output_loss: 1.6512 - val_y1_output_root_mean_squared_error: 0.7282 - val_y2_output_root_mean_squared_error: 1.2850
# Epoch 104/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.8499 - y1_output_loss: 0.7705 - y2_output_loss: 2.0793 - y1_output_root_mean_squared_error: 0.8612 - y2_output_root_mean_squared_error: 1.4336 - val_loss: 2.4819 - val_y1_output_loss: 0.6520 - val_y2_output_loss: 1.8299 - val_y1_output_root_mean_squared_error: 0.8075 - val_y2_output_root_mean_squared_error: 1.3527
# Epoch 105/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.2049 - y1_output_loss: 0.5480 - y2_output_loss: 1.6568 - y1_output_root_mean_squared_error: 0.7390 - y2_output_root_mean_squared_error: 1.2720 - val_loss: 2.3289 - val_y1_output_loss: 0.5319 - val_y2_output_loss: 1.7970 - val_y1_output_root_mean_squared_error: 0.7293 - val_y2_output_root_mean_squared_error: 1.3405
# Epoch 106/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.4608 - y1_output_loss: 0.5790 - y2_output_loss: 1.8818 - y1_output_root_mean_squared_error: 0.7600 - y2_output_root_mean_squared_error: 1.3685 - val_loss: 2.5487 - val_y1_output_loss: 0.4655 - val_y2_output_loss: 2.0832 - val_y1_output_root_mean_squared_error: 0.6823 - val_y2_output_root_mean_squared_error: 1.4433
# Epoch 107/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1398 - y1_output_loss: 0.5371 - y2_output_loss: 1.6028 - y1_output_root_mean_squared_error: 0.7302 - y2_output_root_mean_squared_error: 1.2597 - val_loss: 2.1333 - val_y1_output_loss: 0.4761 - val_y2_output_loss: 1.6572 - val_y1_output_root_mean_squared_error: 0.6900 - val_y2_output_root_mean_squared_error: 1.2873
# Epoch 108/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.7594 - y1_output_loss: 0.5960 - y2_output_loss: 2.1634 - y1_output_root_mean_squared_error: 0.7633 - y2_output_root_mean_squared_error: 1.4650 - val_loss: 1.8171 - val_y1_output_loss: 0.4764 - val_y2_output_loss: 1.3407 - val_y1_output_root_mean_squared_error: 0.6902 - val_y2_output_root_mean_squared_error: 1.1579
# Epoch 109/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.7934 - y1_output_loss: 0.4812 - y2_output_loss: 1.3122 - y1_output_root_mean_squared_error: 0.6907 - y2_output_root_mean_squared_error: 1.1436 - val_loss: 8.0082 - val_y1_output_loss: 1.3454 - val_y2_output_loss: 6.6628 - val_y1_output_root_mean_squared_error: 1.1599 - val_y2_output_root_mean_squared_error: 2.5812
# Epoch 110/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5860 - y1_output_loss: 0.5713 - y2_output_loss: 2.0146 - y1_output_root_mean_squared_error: 0.7509 - y2_output_root_mean_squared_error: 1.4102 - val_loss: 2.0138 - val_y1_output_loss: 0.4213 - val_y2_output_loss: 1.5925 - val_y1_output_root_mean_squared_error: 0.6491 - val_y2_output_root_mean_squared_error: 1.2619
# Epoch 111/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1906 - y1_output_loss: 0.5072 - y2_output_loss: 1.6833 - y1_output_root_mean_squared_error: 0.7107 - y2_output_root_mean_squared_error: 1.2870 - val_loss: 3.9179 - val_y1_output_loss: 1.4884 - val_y2_output_loss: 2.4295 - val_y1_output_root_mean_squared_error: 1.2200 - val_y2_output_root_mean_squared_error: 1.5587
# Epoch 112/500
# 62/62 [==============================] - 0s 5ms/step - loss: 2.1156 - y1_output_loss: 0.5600 - y2_output_loss: 1.5556 - y1_output_root_mean_squared_error: 0.7430 - y2_output_root_mean_squared_error: 1.2412 - val_loss: 2.3124 - val_y1_output_loss: 0.5123 - val_y2_output_loss: 1.8001 - val_y1_output_root_mean_squared_error: 0.7158 - val_y2_output_root_mean_squared_error: 1.3417
# Epoch 113/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.9719 - y1_output_loss: 0.4837 - y2_output_loss: 1.4883 - y1_output_root_mean_squared_error: 0.6944 - y2_output_root_mean_squared_error: 1.2129 - val_loss: 8.5912 - val_y1_output_loss: 2.7992 - val_y2_output_loss: 5.7920 - val_y1_output_root_mean_squared_error: 1.6731 - val_y2_output_root_mean_squared_error: 2.4067
# Epoch 114/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.3255 - y1_output_loss: 0.6607 - y2_output_loss: 1.6648 - y1_output_root_mean_squared_error: 0.8108 - y2_output_root_mean_squared_error: 1.2873 - val_loss: 4.0779 - val_y1_output_loss: 0.7992 - val_y2_output_loss: 3.2788 - val_y1_output_root_mean_squared_error: 0.8940 - val_y2_output_root_mean_squared_error: 1.8107
# Epoch 115/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.3983 - y1_output_loss: 0.8288 - y2_output_loss: 2.5695 - y1_output_root_mean_squared_error: 0.9058 - y2_output_root_mean_squared_error: 1.5913 - val_loss: 2.5312 - val_y1_output_loss: 0.7608 - val_y2_output_loss: 1.7704 - val_y1_output_root_mean_squared_error: 0.8722 - val_y2_output_root_mean_squared_error: 1.3305
# Epoch 116/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.0258 - y1_output_loss: 0.4663 - y2_output_loss: 1.5595 - y1_output_root_mean_squared_error: 0.6810 - y2_output_root_mean_squared_error: 1.2461 - val_loss: 2.1451 - val_y1_output_loss: 0.6987 - val_y2_output_loss: 1.4464 - val_y1_output_root_mean_squared_error: 0.8359 - val_y2_output_root_mean_squared_error: 1.2026
# Epoch 117/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.8132 - y1_output_loss: 0.4104 - y2_output_loss: 1.4028 - y1_output_root_mean_squared_error: 0.6382 - y2_output_root_mean_squared_error: 1.1830 - val_loss: 3.3577 - val_y1_output_loss: 0.8032 - val_y2_output_loss: 2.5546 - val_y1_output_root_mean_squared_error: 0.8962 - val_y2_output_root_mean_squared_error: 1.5983
# Epoch 118/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.3832 - y1_output_loss: 0.5156 - y2_output_loss: 1.8676 - y1_output_root_mean_squared_error: 0.7131 - y2_output_root_mean_squared_error: 1.3632 - val_loss: 3.9036 - val_y1_output_loss: 0.8345 - val_y2_output_loss: 3.0690 - val_y1_output_root_mean_squared_error: 0.9135 - val_y2_output_root_mean_squared_error: 1.7519
# Epoch 119/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1645 - y1_output_loss: 0.5394 - y2_output_loss: 1.6250 - y1_output_root_mean_squared_error: 0.7336 - y2_output_root_mean_squared_error: 1.2712 - val_loss: 1.7786 - val_y1_output_loss: 0.3452 - val_y2_output_loss: 1.4334 - val_y1_output_root_mean_squared_error: 0.5876 - val_y2_output_root_mean_squared_error: 1.1972
# Epoch 120/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.0599 - y1_output_loss: 0.5228 - y2_output_loss: 1.5371 - y1_output_root_mean_squared_error: 0.7142 - y2_output_root_mean_squared_error: 1.2260 - val_loss: 2.3161 - val_y1_output_loss: 0.5348 - val_y2_output_loss: 1.7812 - val_y1_output_root_mean_squared_error: 0.7313 - val_y2_output_root_mean_squared_error: 1.3346
# Epoch 121/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.7080 - y1_output_loss: 0.4125 - y2_output_loss: 1.2955 - y1_output_root_mean_squared_error: 0.6410 - y2_output_root_mean_squared_error: 1.1340 - val_loss: 2.1679 - val_y1_output_loss: 0.4307 - val_y2_output_loss: 1.7372 - val_y1_output_root_mean_squared_error: 0.6563 - val_y2_output_root_mean_squared_error: 1.3180
# Epoch 122/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.6726 - y1_output_loss: 0.4729 - y2_output_loss: 1.1997 - y1_output_root_mean_squared_error: 0.6839 - y2_output_root_mean_squared_error: 1.0925 - val_loss: 2.1027 - val_y1_output_loss: 0.6106 - val_y2_output_loss: 1.4921 - val_y1_output_root_mean_squared_error: 0.7814 - val_y2_output_root_mean_squared_error: 1.2215
# Epoch 123/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3742 - y1_output_loss: 0.1346 - y2_output_loss: 0.2396 - y1_output_root_mean_squared_error: 0.3655 - y2_output_root_mean_squared_error: 0.4785 - val_loss: 0.6867 - val_y1_output_loss: 0.2028 - val_y2_output_loss: 0.4839 - val_y1_output_root_mean_squared_error: 0.4503 - val_y2_output_root_mean_squared_error: 0.6957
# Epoch 462/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.2764 - y1_output_loss: 0.1122 - y2_output_loss: 0.1642 - y1_output_root_mean_squared_error: 0.3333 - y2_output_root_mean_squared_error: 0.4037 - val_loss: 0.7180 - val_y1_output_loss: 0.2407 - val_y2_output_loss: 0.4772 - val_y1_output_root_mean_squared_error: 0.4906 - val_y2_output_root_mean_squared_error: 0.6908
# Epoch 463/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.2985 - y1_output_loss: 0.1039 - y2_output_loss: 0.1945 - y1_output_root_mean_squared_error: 0.3219 - y2_output_root_mean_squared_error: 0.4393 - val_loss: 3.0732 - val_y1_output_loss: 0.3319 - val_y2_output_loss: 2.7413 - val_y1_output_root_mean_squared_error: 0.5761 - val_y2_output_root_mean_squared_error: 1.6557
# Epoch 464/500
# 62/62 [==============================] - 0s 5ms/step - loss: 1.1566 - y1_output_loss: 0.2660 - y2_output_loss: 0.8907 - y1_output_root_mean_squared_error: 0.5057 - y2_output_root_mean_squared_error: 0.9040 - val_loss: 0.9267 - val_y1_output_loss: 0.3324 - val_y2_output_loss: 0.5943 - val_y1_output_root_mean_squared_error: 0.5765 - val_y2_output_root_mean_squared_error: 0.7709
# Epoch 465/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6055 - y1_output_loss: 0.1758 - y2_output_loss: 0.4296 - y1_output_root_mean_squared_error: 0.4175 - y2_output_root_mean_squared_error: 0.6428 - val_loss: 0.7220 - val_y1_output_loss: 0.2117 - val_y2_output_loss: 0.5103 - val_y1_output_root_mean_squared_error: 0.4601 - val_y2_output_root_mean_squared_error: 0.7144
# Epoch 466/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3028 - y1_output_loss: 0.0920 - y2_output_loss: 0.2108 - y1_output_root_mean_squared_error: 0.2983 - y2_output_root_mean_squared_error: 0.4560 - val_loss: 1.0440 - val_y1_output_loss: 0.4174 - val_y2_output_loss: 0.6266 - val_y1_output_root_mean_squared_error: 0.6461 - val_y2_output_root_mean_squared_error: 0.7916
# Epoch 467/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3789 - y1_output_loss: 0.1534 - y2_output_loss: 0.2256 - y1_output_root_mean_squared_error: 0.3904 - y2_output_root_mean_squared_error: 0.4733 - val_loss: 0.9908 - val_y1_output_loss: 0.2840 - val_y2_output_loss: 0.7068 - val_y1_output_root_mean_squared_error: 0.5329 - val_y2_output_root_mean_squared_error: 0.8407
# Epoch 468/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3137 - y1_output_loss: 0.1095 - y2_output_loss: 0.2042 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.4507 - val_loss: 0.6555 - val_y1_output_loss: 0.1826 - val_y2_output_loss: 0.4729 - val_y1_output_root_mean_squared_error: 0.4274 - val_y2_output_root_mean_squared_error: 0.6877
# Epoch 469/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.2966 - y1_output_loss: 0.1166 - y2_output_loss: 0.1801 - y1_output_root_mean_squared_error: 0.3380 - y2_output_root_mean_squared_error: 0.4212 - val_loss: 0.8418 - val_y1_output_loss: 0.2973 - val_y2_output_loss: 0.5445 - val_y1_output_root_mean_squared_error: 0.5453 - val_y2_output_root_mean_squared_error: 0.7379
# Epoch 470/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3642 - y1_output_loss: 0.1172 - y2_output_loss: 0.2470 - y1_output_root_mean_squared_error: 0.3393 - y2_output_root_mean_squared_error: 0.4930 - val_loss: 0.7219 - val_y1_output_loss: 0.2286 - val_y2_output_loss: 0.4933 - val_y1_output_root_mean_squared_error: 0.4781 - val_y2_output_root_mean_squared_error: 0.7024
# Epoch 471/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3520 - y1_output_loss: 0.0981 - y2_output_loss: 0.2539 - y1_output_root_mean_squared_error: 0.3131 - y2_output_root_mean_squared_error: 0.4998 - val_loss: 0.7245 - val_y1_output_loss: 0.1956 - val_y2_output_loss: 0.5289 - val_y1_output_root_mean_squared_error: 0.4422 - val_y2_output_root_mean_squared_error: 0.7273
# Epoch 472/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.2695 - y1_output_loss: 0.1206 - y2_output_loss: 0.1489 - y1_output_root_mean_squared_error: 0.3442 - y2_output_root_mean_squared_error: 0.3809 - val_loss: 0.7487 - val_y1_output_loss: 0.2372 - val_y2_output_loss: 0.5115 - val_y1_output_root_mean_squared_error: 0.4870 - val_y2_output_root_mean_squared_error: 0.7152
# Epoch 473/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4597 - y1_output_loss: 0.1292 - y2_output_loss: 0.3305 - y1_output_root_mean_squared_error: 0.3584 - y2_output_root_mean_squared_error: 0.5742 - val_loss: 0.6821 - val_y1_output_loss: 0.2197 - val_y2_output_loss: 0.4625 - val_y1_output_root_mean_squared_error: 0.4687 - val_y2_output_root_mean_squared_error: 0.6800
# Epoch 474/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3920 - y1_output_loss: 0.1677 - y2_output_loss: 0.2243 - y1_output_root_mean_squared_error: 0.4025 - y2_output_root_mean_squared_error: 0.4707 - val_loss: 0.6751 - val_y1_output_loss: 0.1892 - val_y2_output_loss: 0.4859 - val_y1_output_root_mean_squared_error: 0.4349 - val_y2_output_root_mean_squared_error: 0.6971
# Epoch 475/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4394 - y1_output_loss: 0.1184 - y2_output_loss: 0.3211 - y1_output_root_mean_squared_error: 0.3429 - y2_output_root_mean_squared_error: 0.5523 - val_loss: 0.6752 - val_y1_output_loss: 0.1942 - val_y2_output_loss: 0.4810 - val_y1_output_root_mean_squared_error: 0.4407 - val_y2_output_root_mean_squared_error: 0.6935
# Epoch 476/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3035 - y1_output_loss: 0.0969 - y2_output_loss: 0.2066 - y1_output_root_mean_squared_error: 0.3107 - y2_output_root_mean_squared_error: 0.4538 - val_loss: 0.6553 - val_y1_output_loss: 0.2002 - val_y2_output_loss: 0.4551 - val_y1_output_root_mean_squared_error: 0.4475 - val_y2_output_root_mean_squared_error: 0.6746
# Epoch 477/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3882 - y1_output_loss: 0.1531 - y2_output_loss: 0.2352 - y1_output_root_mean_squared_error: 0.3858 - y2_output_root_mean_squared_error: 0.4828 - val_loss: 2.2026 - val_y1_output_loss: 0.5942 - val_y2_output_loss: 1.6084 - val_y1_output_root_mean_squared_error: 0.7709 - val_y2_output_root_mean_squared_error: 1.2682
# Epoch 478/500
# 62/62 [==============================] - 0s 5ms/step - loss: 1.2362 - y1_output_loss: 0.3140 - y2_output_loss: 0.9223 - y1_output_root_mean_squared_error: 0.5379 - y2_output_root_mean_squared_error: 0.9085 - val_loss: 0.6194 - val_y1_output_loss: 0.1664 - val_y2_output_loss: 0.4530 - val_y1_output_root_mean_squared_error: 0.4079 - val_y2_output_root_mean_squared_error: 0.6730
# Epoch 479/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3251 - y1_output_loss: 0.1053 - y2_output_loss: 0.2198 - y1_output_root_mean_squared_error: 0.3233 - y2_output_root_mean_squared_error: 0.4664 - val_loss: 0.7395 - val_y1_output_loss: 0.1995 - val_y2_output_loss: 0.5400 - val_y1_output_root_mean_squared_error: 0.4466 - val_y2_output_root_mean_squared_error: 0.7349
# Epoch 480/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3161 - y1_output_loss: 0.1050 - y2_output_loss: 0.2111 - y1_output_root_mean_squared_error: 0.3219 - y2_output_root_mean_squared_error: 0.4581 - val_loss: 0.6995 - val_y1_output_loss: 0.2177 - val_y2_output_loss: 0.4818 - val_y1_output_root_mean_squared_error: 0.4666 - val_y2_output_root_mean_squared_error: 0.6941
# Epoch 481/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.2541 - y1_output_loss: 0.0830 - y2_output_loss: 0.1711 - y1_output_root_mean_squared_error: 0.2874 - y2_output_root_mean_squared_error: 0.4123 - val_loss: 0.7117 - val_y1_output_loss: 0.2619 - val_y2_output_loss: 0.4497 - val_y1_output_root_mean_squared_error: 0.5118 - val_y2_output_root_mean_squared_error: 0.6706
# Epoch 482/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3492 - y1_output_loss: 0.1028 - y2_output_loss: 0.2464 - y1_output_root_mean_squared_error: 0.3193 - y2_output_root_mean_squared_error: 0.4949 - val_loss: 0.7454 - val_y1_output_loss: 0.2644 - val_y2_output_loss: 0.4810 - val_y1_output_root_mean_squared_error: 0.5142 - val_y2_output_root_mean_squared_error: 0.6935
# Epoch 483/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3585 - y1_output_loss: 0.1100 - y2_output_loss: 0.2486 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.4975 - val_loss: 0.6471 - val_y1_output_loss: 0.1758 - val_y2_output_loss: 0.4713 - val_y1_output_root_mean_squared_error: 0.4193 - val_y2_output_root_mean_squared_error: 0.6865
# Epoch 484/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4930 - y1_output_loss: 0.1307 - y2_output_loss: 0.3623 - y1_output_root_mean_squared_error: 0.3594 - y2_output_root_mean_squared_error: 0.5935 - val_loss: 0.8314 - val_y1_output_loss: 0.1914 - val_y2_output_loss: 0.6400 - val_y1_output_root_mean_squared_error: 0.4375 - val_y2_output_root_mean_squared_error: 0.8000
# Epoch 485/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4873 - y1_output_loss: 0.1524 - y2_output_loss: 0.3350 - y1_output_root_mean_squared_error: 0.3887 - y2_output_root_mean_squared_error: 0.5687 - val_loss: 0.6784 - val_y1_output_loss: 0.2138 - val_y2_output_loss: 0.4646 - val_y1_output_root_mean_squared_error: 0.4624 - val_y2_output_root_mean_squared_error: 0.6816
# Epoch 486/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3096 - y1_output_loss: 0.1125 - y2_output_loss: 0.1971 - y1_output_root_mean_squared_error: 0.3350 - y2_output_root_mean_squared_error: 0.4433 - val_loss: 1.0077 - val_y1_output_loss: 0.4468 - val_y2_output_loss: 0.5609 - val_y1_output_root_mean_squared_error: 0.6684 - val_y2_output_root_mean_squared_error: 0.7489
# Epoch 487/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3168 - y1_output_loss: 0.1194 - y2_output_loss: 0.1974 - y1_output_root_mean_squared_error: 0.3412 - y2_output_root_mean_squared_error: 0.4429 - val_loss: 0.9276 - val_y1_output_loss: 0.3648 - val_y2_output_loss: 0.5627 - val_y1_output_root_mean_squared_error: 0.6040 - val_y2_output_root_mean_squared_error: 0.7502
# Epoch 488/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3925 - y1_output_loss: 0.1431 - y2_output_loss: 0.2494 - y1_output_root_mean_squared_error: 0.3763 - y2_output_root_mean_squared_error: 0.4991 - val_loss: 0.6732 - val_y1_output_loss: 0.2025 - val_y2_output_loss: 0.4707 - val_y1_output_root_mean_squared_error: 0.4499 - val_y2_output_root_mean_squared_error: 0.6861
# Epoch 489/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3028 - y1_output_loss: 0.1060 - y2_output_loss: 0.1968 - y1_output_root_mean_squared_error: 0.3254 - y2_output_root_mean_squared_error: 0.4411 - val_loss: 0.9458 - val_y1_output_loss: 0.2913 - val_y2_output_loss: 0.6544 - val_y1_output_root_mean_squared_error: 0.5397 - val_y2_output_root_mean_squared_error: 0.8090
# Epoch 490/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4237 - y1_output_loss: 0.1110 - y2_output_loss: 0.3127 - y1_output_root_mean_squared_error: 0.3325 - y2_output_root_mean_squared_error: 0.5517 - val_loss: 0.9376 - val_y1_output_loss: 0.3618 - val_y2_output_loss: 0.5758 - val_y1_output_root_mean_squared_error: 0.6015 - val_y2_output_root_mean_squared_error: 0.7588
# Epoch 491/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3243 - y1_output_loss: 0.1133 - y2_output_loss: 0.2110 - y1_output_root_mean_squared_error: 0.3355 - y2_output_root_mean_squared_error: 0.4569 - val_loss: 0.8745 - val_y1_output_loss: 0.2058 - val_y2_output_loss: 0.6687 - val_y1_output_root_mean_squared_error: 0.4536 - val_y2_output_root_mean_squared_error: 0.8177
# Epoch 492/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4421 - y1_output_loss: 0.1197 - y2_output_loss: 0.3224 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.5642 - val_loss: 0.7208 - val_y1_output_loss: 0.2231 - val_y2_output_loss: 0.4977 - val_y1_output_root_mean_squared_error: 0.4724 - val_y2_output_root_mean_squared_error: 0.7055
# Epoch 493/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.2635 - y1_output_loss: 0.1022 - y2_output_loss: 0.1613 - y1_output_root_mean_squared_error: 0.3192 - y2_output_root_mean_squared_error: 0.4009 - val_loss: 0.9413 - val_y1_output_loss: 0.2469 - val_y2_output_loss: 0.6944 - val_y1_output_root_mean_squared_error: 0.4969 - val_y2_output_root_mean_squared_error: 0.8333
# Epoch 494/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4116 - y1_output_loss: 0.1282 - y2_output_loss: 0.2834 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5204 - val_loss: 0.6868 - val_y1_output_loss: 0.2191 - val_y2_output_loss: 0.4677 - val_y1_output_root_mean_squared_error: 0.4681 - val_y2_output_root_mean_squared_error: 0.6839
# Epoch 495/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.2324 - y1_output_loss: 0.0937 - y2_output_loss: 0.1386 - y1_output_root_mean_squared_error: 0.3056 - y2_output_root_mean_squared_error: 0.3709 - val_loss: 0.9684 - val_y1_output_loss: 0.1825 - val_y2_output_loss: 0.7859 - val_y1_output_root_mean_squared_error: 0.4272 - val_y2_output_root_mean_squared_error: 0.8865
# Epoch 496/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5233 - y1_output_loss: 0.1483 - y2_output_loss: 0.3750 - y1_output_root_mean_squared_error: 0.3813 - y2_output_root_mean_squared_error: 0.6056 - val_loss: 0.8914 - val_y1_output_loss: 0.2761 - val_y2_output_loss: 0.6154 - val_y1_output_root_mean_squared_error: 0.5254 - val_y2_output_root_mean_squared_error: 0.7845
# Epoch 497/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3752 - y1_output_loss: 0.1046 - y2_output_loss: 0.2706 - y1_output_root_mean_squared_error: 0.3232 - y2_output_root_mean_squared_error: 0.5141 - val_loss: 0.6934 - val_y1_output_loss: 0.2138 - val_y2_output_loss: 0.4796 - val_y1_output_root_mean_squared_error: 0.4624 - val_y2_output_root_mean_squared_error: 0.6925
# Epoch 498/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4193 - y1_output_loss: 0.1384 - y2_output_loss: 0.2809 - y1_output_root_mean_squared_error: 0.3708 - y2_output_root_mean_squared_error: 0.5278 - val_loss: 0.7089 - val_y1_output_loss: 0.2154 - val_y2_output_loss: 0.4935 - val_y1_output_root_mean_squared_error: 0.4642 - val_y2_output_root_mean_squared_error: 0.7025
# Epoch 499/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3728 - y1_output_loss: 0.1260 - y2_output_loss: 0.2468 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.4807 - val_loss: 0.7706 - val_y1_output_loss: 0.2124 - val_y2_output_loss: 0.5581 - val_y1_output_root_mean_squared_error: 0.4609 - val_y2_output_root_mean_squared_error: 0.7471
# Epoch 500/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3858 - y1_output_loss: 0.1099 - y2_output_loss: 0.2759 - y1_output_root_mean_squared_error: 0.3303 - y2_output_root_mean_squared_error: 0.5216 - val_loss: 0.7080 - val_y1_output_loss: 0.2188 - val_y2_output_loss: 0.4891 - val_y1_output_root_mean_squared_error: 0.4678 - val_y2_output_root_mean_squared_error: 0.6994

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7080 - y1_output_loss: 0.2188 - y2_output_loss: 0.4891 - y1_output_root_mean_squared_error: 0.4678 - y2_output_root_mean_squared_error: 0.6994
# Loss = 0.7079554796218872, Y1_loss = 0.21884731948375702, Y1_mse = 0.4678111970424652, Y2_loss = 0.48910823464393616, Y2_mse = 0.6993627548217773

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
